# %% [markdown]
# <a href="https://colab.research.google.com/github/currencyfxjle/Solar-Mini-Calculator-Back-Up/blob/main/List_with_documentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Constants**

# %%
# Define numeric values for cells in column B (likely representing key input numbers such as revenue, costs, or thresholds)
B5 = 11600          # Value for cell B5
B6 = 47149          # Value for cell B6
B7 = 100524         # Value for cell B7
B8 = 191949         # Value for cell B8
B9 = 243724         # Value for cell B9
B10 = 609349        # Value for cell B10
B14 = 16549         # Value for cell B14
B15 = 63099         # Value for cell B15
B16 = 100499        # Value for cell B16
B17 = 191949        # Value for cell B17
B18 = 243699        # Value for cell B18
B19 = 609349        # Value for cell B19
B23 = 23199         # Value for cell B23
B24 = 94299         # Value for cell B24
B25 = 201049        # Value for cell B25
B26 = 383899        # Value for cell B26
B27 = 487449        # Value for cell B27
B28 = 731199        # Value for cell B28

# Define decimal values for cells in column D (possibly representing percentages or ratios)
D5 = 0.1            # Value for cell D5 (10%)
D6 = 0.12           # Value for cell D6 (12%)
D7 = 0.22           # Value for cell D7 (22%)
D8 = 0.24           # Value for cell D8 (24%)
D9 = 0.32           # Value for cell D9 (32%)
D10 = 0.35          # Value for cell D10 (35%)
D11 = 0.37          # Value for cell D11 (37%)
D14 = 0.1           # Value for cell D14 (10%)
D15 = 0.12          # Value for cell D15 (12%)
D16 = 0.22          # Value for cell D16 (22%)
D17 = 0.24          # Value for cell D17 (24%)
D18 = 0.32          # Value for cell D18 (32%)
D19 = 0.35          # Value for cell D19 (35%)
D20 = 0.37          # Value for cell D20 (37%)
D23 = 0.1           # Value for cell D23 (10%)
D24 = 0.12          # Value for cell D24 (12%)
D25 = 0.22          # Value for cell D25 (22%)
D26 = 0.24          # Value for cell D26 (24%)
D27 = 0.32          # Value for cell D27 (32%)
D28 = 0.35          # Value for cell D28 (35%)
D29 = 0.37          # Value for cell D29 (37%)

# Define values for cells in column A.
# Many values are defined as one more than the corresponding value in column B,
# likely to create an index or boundary marker.
A5 = 0              # Starting point for A5, set to zero
A6 = 11600        # A6 is set equal to B5 (11600)
A14 = 0            # A14 is zero
A15 = B14 + 1      # A15 is one more than B14
A16 = B15 + 1      # A16 is one more than B15
A17 = B16 + 1      # A17 is one more than B16
A18 = B17 + 1      # A18 is one more than B17
A19 = B18 + 1      # A19 is one more than B18
A20 = B19 + 1      # A20 is one more than B19
A23 = 0            # A23 is zero
A24 = B23 + 1      # A24 is one more than B23
A25 = B24 + 1      # A25 is one more than B24
A26 = B25 + 1      # A26 is one more than B25
A27 = B26 + 1      # A27 is one more than B26
A28 = B27 + 1      # A28 is one more than B27
A29 = B28 + 1      # A29 is one more than B28

# Define values for cells in column C (these could represent calculations or baseline values)
C5 = 0            # C5 is zero

C14 = 0           # C14 is zero
C15 = 1335        # C15 is set to 1335.
                  # --> [CORRECTION:] Based on help text, bonus depreciation used should be 60%
                  #     so consider revising bonus_depreciation_used below accordingly.
C16 = 6952.50     # C16 is set to 6952.50
C17 = 27052.50    # C17 is set to 27052.50
C18 = 49816.50    # C18 is set to 49816.50
C19 = 117202.50   # C19 is set to 117202.50
C20 = 126950      # C20 is set to 126950 (this value is later used for the ITC rate)
C23 = 0           # C23 is zero

# Define additional variables for calculation rates and statuses
itc_rate = 40     # Investment Tax Credit rate (percentage)
FAMILY_STATUS = 'MFJ'   # Family status, likely "Married Filing Jointly"

# [CORRECTION:] The help text indicates bonus depreciation used (c15) should be 60%,
# so update bonus_depreciation_used to 60 instead of 40.
bonus_depreciation_used = 60

# Annual escalator rate. (Note: The help text later references a value of 2.99% in some calculations.)
# You might want to update this if required; here it is defined as 2.475%.
annual_escalator = 2.475 / 100

# Define fractions (or percentage rates) for various factors/parameters
# [CORRECTION:] f14 is defined as the bonus depreciation percentage.
# Help text indicates it should be 60% (not 40%), so update accordingly.
f14 = 60 / 100    # 60% bonus depreciation is applied
f18 = 20 / 100    # Additional depreciation rate (20%)
c17 = 37 / 100    # Federal tax rate (37%)
# [CORRECTION:] The help text suggests a state tax adjustment factor of 15%.
# So c14 is updated from 13.5% to 15%.
c14 = 15 / 100    # State tax adjustment factor (15%)
# [POSSIBLE CORRECTION:] f12 is sometimes referenced as 4.50 instead of 3.95.
# Review if f12 should be updated; for now, we'll leave it as is.
f12 = 3.95 / 100
i18 = 11.52 / 100 # Rate (11.52%)
j18 = 11.52 / 100 # Rate (11.52%)
k18 = 5.76 / 100  # Rate (5.76%)
h18 = 19.2 / 100  # Rate (19.2%)
i12 = 25          # A constant (could be a count or another parameter)
g18 = 32 / 100    # Rate (32%)

# Define environmental or resource-related factors
f6 = 610      # f6 represents a carbon dioxide factor value
f7 = 28       # f7 represents the number of trees (could relate to carbon offset)
f8 = 0.55     # f8 represents a factor for coal usage/emission
f9 = 0.13     # f9 represents a factor for vehicles (emissions or similar)

# Generate a tuple of cell references from AC2 to BK2 (total 35 cells),
# possibly for further data mapping or iterative calculations.
ac2, ad2, ae2, af2, ag2, ah2, ai2, aj2, ak2, al2, am2, an2, ao2, ap2, aq2, ar2, as2, at2, au2, av2, aw2, ax2, ay2, az2, ba2, bb2, bc2, bd2, be2, bf2, bg2, bh2, bi2, bj2, bk2 = tuple(range(1, 36))

# Define Revenue Ratio dictionaries for different time periods (Pre-July and Post-July)
PREJULY = {
    # Each state key maps to a list of three values (likely representing revenue ratios in different scenarios or time periods)
    'Alabama': [3.7, 4.345, 2.5],
    'Alaska': [3.75, 4.345, 2.56],
    'Arizona': [3.7, 4.345, 2.56],
    'Arkansas': [3.8, 4.345, 2.56],
    'California': [3.8, 4.345, 2.56],
    'Colorado': [3.6, 4.345, 2.56],
    'Connecticut': [3.6, 4.345, 2.56],
    'Delaware': [3.6, 4.345, 2.56],
    'District of Columbia': [3.6, 4.345, 2.56],
    'Florida': [3.75, 4.345, 2.56],
    'Georgia': [3.8, 4.345, 2.6],
    'Hawaii': [3.65, 4.345, 2.6],
    'Idaho': [3.65, 4.345, 2.6],
    'Illinois': [3.7, 4.345, 2.6],
    'Indiana': [3.7, 4.345, 2.6],
    'Iowa': [3.7, 4.345, 2.6],
    'Kansas': [3.8, 4.345, 2.6],
    'Kentucky': [3.7, 4.345, 2.6],
    'Louisiana': [3.8, 4.345, 2.6],
    'Maine': [3.8, 4.345, 2.6],
    'Maryland': [3.8, 4.345, 2.6],
    'Maryland - Baltimore County': [3.8, 4.345, 2.6],
    'Maryland - Montgomery Co.': [3.8, 4.345, 2.6],
    'Maryland - Prince George\'s Co.': [3.8, 4.345, 2.6],
    'Massachusetts': [3.8, 4.345, 2.6],
    'Michigan': [3.8, 4.345, 2.6],
    'Minnesota': [3.75, 4.345, 2.6],
    'Mississippi': [3.7, 4.345, 2.6],
    'Missouri': [3.7, 4.345, 2.6],
    'Montana': [3.75, 4.345, 2.6],
    'Nebraska': [3.75, 4.345, 2.6],
    'Nevada': [3.75, 4.345, 2.56],
    'New Hampshire': [3.75, 4.345, 2.56],
    'New Jersey': [3.8, 4.345, 2.6],
    'New Mexico': [3.8, 4.345, 2.6],
    'New York': [3.8, 4.345, 2.6],
    'New York - NYC': [3.8, 4.345, 2.6],
    'New York - Yonkers': [3.8, 4.345, 2.6],
    'North Carolina': [3.82, 4.345, 2.6],
    'North Dakota': [3.8, 4.345, 2.6],
    'Ohio': [3.8, 4.345, 2.6],
    'Oklahoma': [3.8, 4.345, 2.6],
    'Oregon': [3.8, 4.345, 2.6],
    'Oregon - Clackamas County': [3.8, 4.345, 2.6],
    'Oregon - Multnomah County': [3.8, 4.345, 2.6],
    'Oregon - Washington County': [3.8, 4.345, 2.6],
    'Pennsylvania': [3.7, 4.345, 2.6],
    'Rhode Island': [3.8, 4.345, 2.6],
    'South Carolina': [3.8, 4.345, 2.6],
    'South Dakota': [3.75, 4.345, 2.56],
    'Tennessee': [3.75, 4.345, 2.56],
    'Texas': [3.75, 4.345, 2.56],
    'Utah': [3.8, 4.345, 2.6],
    'Vermont': [3.7, 4.345, 2.6],
    'Virginia': [3.8, 4.345, 2.6],
    'Washington': [3.75, 4.345, 2.56],
    'West Virginia': [3.8, 4.345, 2.6],
    'Wisconsin': [3.8, 4.345, 2.6],
    'Wyoming': [3.75, 4.345, 2.56]
}

POSTJULY = {
    # Similar structure to PREJULY, but with the second value in each list updated (likely reflecting a post-July scenario)
    'Alabama': [3.7, 2.735, 2.5],
    'Alaska': [3.75, 2.735, 2.56],
    'Arizona': [3.7, 2.735, 2.56],
    'Arkansas': [3.8, 2.735, 2.56],
    'California': [3.8, 2.735, 2.56],
    'Colorado': [3.6, 2.735, 2.56],
    'Connecticut': [3.6, 2.735, 2.56],
    'Delaware': [3.6, 2.735, 2.56],
    'District of Columbia': [3.6, 2.735, 2.56],
    'Florida': [3.75, 2.735, 2.56],
    'Georgia': [3.8, 2.735, 2.6],
    'Hawaii': [3.65, 2.735, 2.6],
    'Idaho': [3.65, 2.735, 2.6],
    'Illinois': [3.7, 2.735, 2.6],
    'Indiana': [3.7, 2.735, 2.6],
    'Iowa': [3.7, 2.735, 2.6],
    'Kansas': [3.8, 2.735, 2.6],
    'Kentucky': [3.7, 2.735, 2.6],
    'Louisiana': [3.8, 2.735, 2.6],
    'Maine': [3.8, 2.735, 2.6],
    'Maryland': [3.8, 2.735, 2.6],
    'Maryland - Baltimore County': [3.8, 2.735, 2.6],
    'Maryland - Montgomery Co.': [3.8, 2.735, 2.6],
    'Maryland - Prince George\'s Co.': [3.8, 2.735, 2.6],
    'Massachusetts': [3.8, 2.735, 2.6],
    'Michigan': [3.8, 2.735, 2.6],
    'Minnesota': [3.75, 2.735, 2.6],
    'Mississippi': [3.7, 2.735, 2.6],
    'Missouri': [3.7, 2.735, 2.6],
    'Montana': [3.75, 2.735, 2.6],
    'Nebraska': [3.75, 2.735, 2.6],
    'Nevada': [3.75, 2.735, 2.56],
    'New Hampshire': [3.75, 2.735, 2.56],
    'New Jersey': [3.8, 2.735, 2.6],
    'New Mexico': [3.8, 2.735, 2.6],
    'New York': [3.8, 2.735, 2.6],
    'New York - NYC': [3.8, 2.735, 2.6],
    'New York - Yonkers': [3.8, 2.735, 2.6],
    'North Carolina': [3.82, 2.735, 2.6],
    'North Dakota': [3.8, 2.735, 2.6],
    'Ohio': [3.8, 2.735, 2.6],
    'Oklahoma': [3.8, 2.735, 2.6],
    'Oregon': [3.8, 2.735, 2.6],
    'Oregon - Clackamas County': [3.8, 2.735, 2.6],
    'Oregon - Multnomah County': [3.8, 2.735, 2.6],
    'Oregon - Washington County': [3.8, 2.735, 2.6],
    'Pennsylvania': [3.7, 2.735, 2.6],
    'Rhode Island': [3.8, 2.735, 2.6],
    'South Carolina': [3.8, 2.735, 2.6],
    'South Dakota': [3.75, 2.735, 2.56],
    'Tennessee': [3.75, 2.735, 2.56],
    'Texas': [3.75, 2.735, 2.56],
    'Utah': [3.8, 2.735, 2.6],
    'Vermont': [3.7, 2.735, 2.6],
    'Virginia': [3.8, 2.735, 2.6],
    'Washington': [3.75, 2.735, 2.56],
    'West Virginia': [3.8, 2.735, 2.6],
    'Wisconsin': [3.8, 2.735, 2.6],
    'Wyoming': [3.75, 2.735, 2.56]
}

# Define tax rate dictionaries for pre-July and post-July scenarios.
PRE_JULY_TAX_RATE = {
    # Each key is a state with its corresponding tax rate (possibly as percentages)
    'Alabama': 3.15,
    'Alaska': 0,
    'Arizona': 2.5,
    'Arkansas': 5.5,
    'California': 14.3,
    'Colorado': 4.55,
    'Connecticut': 6.99,
    'Delaware': 6.6,
    'District of Columbia': 10.75,
    'Florida': 0,
    'Georgia': 5.75,
    'Hawaii': 11,
    'Idaho': 6.5,
    'Illinois': 4.95,
    'Indiana': 3.05,
    'Iowa': 5.37,
    'Kansas': 5.7,
    'Kentucky': 5,
    'Louisiana': 4.25,
    'Maine': 7.15,
    'Maryland': 5.75,
    'Maryland - Baltimore County': 8.95,
    'Maryland - Montgomery Co.': 8.95,
    'Maryland - Prince George\'s Co.': 8.95,
    'Massachusetts': 9,
    'Michigan': 4.25,
    'Minnesota': 9.85,
    'Mississippi': 5,
    'Missouri': 5.3,
    'Montana': 6.75,
    'Nebraska': 6.84,
    'Nevada': 0,
    'New Hampshire': 0,
    'New Jersey': 10.75,
    'New Mexico': 5.9,
    'New York': 10.9,
    'New York - NYC': 10.9,
    'New York - Yonkers': 10.9,
    'North Carolina': 4.99,
    'North Dakota': 2.9,
    'Ohio': 3.5,
    'Oklahoma': 4.75,
    'Oregon': 9.9,
    'Oregon - Clackamas County': 10.9,
    'Oregon - Multnomah County': 13.9,
    'Oregon - Washington County': 10.9,
    'Pennsylvania': 3.07,
    'Rhode Island': 5.99,
    'South Carolina': 7,
    'South Dakota': 0,
    'Tennessee': 0,
    'Texas': 0,
    'Utah': 6,
    'Vermont': 5,
    'Virginia': 5.75,
    'Washington': 0,
    'West Virginia': 5.12,
    'Wisconsin': 5,
    'Wyoming': 0
}

POST_JULY_TAX_RATE = {
    # In this dataset the Post-July tax rates are the same as the Pre-July rates.
    'Alabama': 3.15,
    'Alaska': 0,
    'Arizona': 2.5,
    'Arkansas': 5.5,
    'California': 14.3,
    'Colorado': 4.55,
    'Connecticut': 6.99,
    'Delaware': 6.6,
    'District of Columbia': 10.75,
    'Florida': 0,
    'Georgia': 5.75,
    'Hawaii': 11,
    'Idaho': 6.5,
    'Illinois': 4.95,
    'Indiana': 3.05,
    'Iowa': 5.37,
    'Kansas': 5.7,
    'Kentucky': 5,
    'Louisiana': 4.25,
    'Maine': 7.15,
    'Maryland': 5.75,
    'Maryland - Baltimore County': 8.95,
    'Maryland - Montgomery Co.': 8.95,
    'Maryland - Prince George\'s Co.': 8.95,
    'Massachusetts': 9,
    'Michigan': 4.25,
    'Minnesota': 9.85,
    'Mississippi': 5,
    'Missouri': 5.3,
    'Montana': 6.75,
    'Nebraska': 6.84,
    'Nevada': 0,
    'New Hampshire': 0,
    'New Jersey': 10.75,
    'New Mexico': 5.9,
    'New York': 10.9,
    'New York - NYC': 10.9,
    'New York - Yonkers': 10.9,
    'North Carolina': 4.99,
    'North Dakota': 2.9,
    'Ohio': 3.5,
    'Oklahoma': 4.75,
    'Oregon': 9.9,
    'Oregon - Clackamas County': 10.9,
    'Oregon - Multnomah County': 13.9,
    'Oregon - Washington County': 10.9,
    'Pennsylvania': 3.07,
    'Rhode Island': 5.99,
    'South Carolina': 7,
    'South Dakota': 0,
    'Tennessee': 0,
    'Texas': 0,
    'Utah': 6,
    'Vermont': 5,
    'Virginia': 5.75,
    'Washington': 0,
    'West Virginia': 5.12,
    'Wisconsin': 5,
    'Wyoming': 0
}

# Define Cash Ratio dictionaries for acquisition prices (cash values) before and after July.
PRE_JULY_ACQUISITION_PRICE_CASH = {
    # Each state key maps to a list of three values representing acquisition price cash ratios
    'Alabama': [52, 63, 61],
    'Alaska': [51, 63, 60],
    'Arizona': [52, 63, 61],
    'Arkansas': [53.85, 63, 62],
    'California': [56.6, 63, 64.35],
    'Colorado': [52.5, 63, 62],
    'Connecticut': [54, 63, 63.5],
    'Delaware': [53.8, 63, 63],
    'District of Columbia': [55, 63, 64],
    'Florida': [51, 64, 60],
    'Georgia': [54, 63, 63],
    'Hawaii': [55, 63, 64.4],
    'Idaho': [54, 63, 63.25],
    'Illinois': [53.5, 63, 62.5],
    'Indiana': [52, 63, 61],
    'Iowa': [53.2, 63, 62],
    'Kansas': [54, 63, 62.5],
    'Kentucky': [53.5, 63, 62],
    'Louisiana': [53.5, 63, 61.5],
    'Maine': [54, 63, 62],
    'Maryland': [54, 63, 62.5],
    'Maryland - Baltimore County': [55.5, 63, 63.5],
    'Maryland - Montgomery Co.': [55.5, 63, 63.5],
    'Maryland - Prince George\'s Co.': [55.5, 63, 63.5],
    'Massachusetts': [55.5, 63, 63.5],
    'Michigan': [53.5, 63, 61.5],
    'Minnesota': [55, 63, 63.4],
    'Mississippi': [53.5, 63, 62],
    'Missouri': [54, 63, 62],
    'Montana': [55, 63, 63.5],
    'Nebraska': [55, 63, 63.5],
    'Nevada': [51, 63, 60],
    'New Hampshire': [51, 63, 60],
    'New Jersey': [56, 63, 64],
    'New Mexico': [54.15, 63, 62.5],
    'New York': [56, 63, 64],
    'New York - NYC': [56, 63, 64],
    'New York - Yonkers': [56, 63, 64],
    'North Carolina': [53.5, 63, 62],
    'North Dakota': [52.75, 63, 61.5],
    'Ohio': [53, 63, 61.5],
    'Oklahoma': [54, 63, 62.5],
    'Oregon': [55.5, 63, 63.5],
    'Oregon - Clackamas County': [56, 63, 64.25],
    'Oregon - Multnomah County': [58, 63, 66],
    'Oregon - Washington County': [56, 63, 64.25],
    'Pennsylvania': [52, 63, 61],
    'Rhode Island': [54.25, 63, 62.75],
    'South Carolina': [55.15, 63, 63.5],
    'South Dakota': [51, 63, 60],
    'Tennessee': [51, 63, 60],
    'Texas': [51, 63, 60],
    'Utah': [54.25, 63, 62.75],
    'Vermont': [53.5, 63, 62],
    'Virginia': [54, 63, 62.5],
    'Washington': [51, 63, 60],
    'West Virginia': [54, 63, 62.5],
    'Wisconsin': [53.4, 63, 62],
    'Wyoming': [51, 63, 60]
}

POST_JULY_ACQUISITION_PRICE_CASH = {
    # Each state key maps to a list of three updated values for acquisition price cash ratios after July.
    'Alabama': [53.5, 64, 62.5],
    'Alaska': [53.4, 63, 62.8],
    'Arizona': [53, 64, 62.3],
    'Arkansas': [55, 65, 64],
    'California': [59, 63, 66.9],
    'Colorado': [53.9, 64, 63.4],
    'Connecticut': [55.5, 65, 65],
    'Delaware': [55.4, 65, 65],
    'District of Columbia': [57.5, 66, 66.7],
    'Florida': [53.4, 63, 62.8],
    'Georgia': [56, 65, 64.8],
    'Hawaii': [58, 66, 67],
    'Idaho': [55.4, 65, 65],
    'Illinois': [54.5, 64, 63.8],
    'Indiana': [53, 64, 62.4],
    'Iowa': [55, 64, 64.2],
    'Kansas': [55.4, 64.5, 64.2],
    'Kentucky': [54.7, 64.5, 64],
    'Louisiana': [54.2, 64, 63],
    'Maine': [55.3, 65, 63.8],
    'Maryland': [55.4, 64.5, 64],
    'Maryland - Baltimore County': [57.5, 65.5, 66],
    'Maryland - Montgomery Co.': [57.5, 65.5, 66],
    'Maryland - Prince George\'s Co.': [57.5, 65.5, 66],
    'Massachusetts': [57, 65, 65.5],
    'Michigan': [54.2, 64, 63],
    'Minnesota': [57.4, 65.5, 66.1],
    'Mississippi': [54.7, 64.5, 64],
    'Missouri': [54.7, 64.5, 63.9],
    'Montana': [56.2, 65, 65],
    'Nebraska': [56.2, 65, 65],
    'Nevada': [53.4, 63, 62.8],
    'New Hampshire': [53.4, 63, 62.8],
    'New Jersey': [58.5, 66, 66.9],
    'New Mexico': [55.4, 64.5, 64],
    'New York': [58.5, 66, 67],
    'New York - NYC': [58.5, 66, 67],
    'New York - Yonkers': [58.5, 66, 67],
    'North Carolina': [54.9, 64.5, 63.5],
    'North Dakota': [53.5, 64, 62.3],
    'Ohio': [53.8, 64, 62.5],
    'Oklahoma': [55, 64.5, 63.8],
    'Oregon': [57.7, 65.5, 66.2],
    'Oregon - Clackamas County': [58.5, 66, 67],
    'Oregon - Multnomah County': [61.2, 66.5, 69.8],
    'Oregon - Washington County': [58.5, 66, 67],
    'Pennsylvania': [53, 64, 62.4],
    'Rhode Island': [55.7, 64.5, 64.5],
    'South Carolina': [55.7, 65, 64.3],
    'South Dakota': [53.4, 63, 62.8],
    'Tennessee': [53.4, 63, 62.8],
    'Texas': [53.4, 63, 62.8],
    'Utah': [55.6, 64.5, 64.3],
    'Vermont': [54.7, 64.5, 64],
    'Virginia': [55.3, 65, 64],
    'Washington': [53.4, 63, 62.8],
    'West Virginia': [55, 64.5, 63.8],
    'Wisconsin': [54.7, 64.5, 64],
    'Wyoming': [53.4, 63, 62.8]
}

# Define a tuple of email addresses (likely for contact or notification purposes)
EMAILS = (
    'akobirtursunov80@gmail.com',
    'deskart.apps@gmail.com',
)

# %% [markdown]
# # **Calculations.py**

# %%
# Import all constants from the local constants module
from .constants import *

# Create new cell values in column A by adding 1 to specific cells in column B
A7 = B6 + 1      # A7 is one greater than B6
A8 = B7 + 1      # A8 is one greater than B7
A9 = B8 + 1      # A9 is one greater than B8
A10 = B9 + 1     # A10 is one greater than B9
A11 = B10 + 1    # A11 is one greater than B10

# Compute cumulative values in column C (cells C24 through C29) using differences between B cells multiplied by corresponding D percentages
C24 = B23 * D23                               # C24: Applies rate D23 to the value in B23
C25 = C24 + (B24 - B23) * D24                   # C25: Starts with C24 and adds the increment from B24 to B23 at rate D24
C26 = C25 + (B25 - B24) * D25                   # C26: Continues by adding the increment from B25 to B24 at rate D25
C27 = C26 + (B26 - B25) * D26                   # C27: Adds the next increment from B26 to B25 at rate D26
C28 = C27 + (B27 - B26) * D27                   # C28: Adds the difference from B27 to B26 at rate D27
C29 = C28 + (B28 - B27) * D28                   # C29: Final cumulative value, adding the difference from B28 to B27 at rate D28

# Compute cumulative values in column C (cells C6 through C11) similarly, using differences between B cells multiplied by D percentages
C6 = B5 * D5                                  # C6: Applies rate D5 to the value in B5
C7 = C6 + (B6 - B5) * D6                        # C7: Adds the incremental difference (B6 - B5) at rate D6 to C6
C8 = C7 + (B7 - B6) * D7                        # C8: Continues by adding (B7 - B6) multiplied by D7
C9 = C8 + (B8 - B7) * D8                        # C9: Adds the difference from B8 to B7 at rate D8
C10 = C9 + (B9 - B8) * D9                       # C10: Adds the difference from B9 to B8 at rate D9
C11 = C10 + (B10 - B9) * D10                     # C11: Adds the difference from B10 to B9 at rate D10

# Calculate modified rates using defined variables (from imported constants)
f13 = 1 - ((itc_rate / 100) / 2)  # f13: Adjusts the Investment Tax Credit (itc_rate) by halving its percentage and subtracting from 1

# Compute derived values using the adjusted rate f13 and other rate constants (i18 and h18)
i15 = 0.4 * f13 * i18    # i15: 40% of the product of f13 and i18; likely represents an intermediate calculation
h15 = 0.4 * f13 * h18    # h15: 40% of the product of f13 and h18; similar in nature to i15

# %% [markdown]
# # **utils.py**

# %%
from datetime import datetime
import numpy as np
from django.core.mail import send_mail

# Import custom settings and calculation functions from local modules.
from . import settings
from .calculations import *


def calculate_mfj(m5):
    """
    Calculate the federal liability for Married Filing Jointly (MFJ) based on the input m5.

    The calculation is broken into several segments (mfj1 to mfj7) that depend on the value of m5
    relative to predefined thresholds (cells B23, A24, B24, etc.) and uses corresponding percentage rates (D23, D24, etc.)
    and base adjustment values (C23, C24, etc.).
    """
    mfj1 = (m5 * 0.1) + C23 if m5 < B23 else 0
    mfj2 = ((m5 - A24) * D24) + C24 if B24 > m5 > A24 else 0
    mfj3 = ((m5 - A25) * D25) + C25 if A25 < m5 < B25 else 0
    mfj4 = ((m5 - A26) * D26) + C26 if A26 < m5 < B26 else 0
    mfj5 = ((m5 - A27) * D27) + C27 if A27 < m5 < B27 else 0
    mfj6 = ((m5 - A28) * D28) + C28 if A28 < m5 < B28 else 0
    mfj7 = ((m5 - A29) * D29) + C29 if m5 > A29 else 0

    # Return the sum of all the segments.
    return sum([mfj1, mfj2, mfj3, mfj4, mfj5, mfj6, mfj7])


def calculate_hoh(m5):
    """
    Calculate the federal liability for Head of Household (HOH) based on the input m5.

    Similar to the MFJ calculation, the HOH liability is split into segments (hoh1 to hoh7)
    that depend on the input value m5 and predefined thresholds and rates.
    """
    hoh1 = (m5 * 0.1) + C14 if m5 < B14 else 0
    hoh2 = ((m5 - A15) * D15) + C15 if A15 < m5 < B15 else 0
    hoh3 = ((m5 - A16) * D16) + C16 if A16 < m5 < B16 else 0
    hoh4 = ((m5 - A17) * D17) + C17 if A17 < m5 < B17 else 0
    hoh5 = ((m5 - A18) * D18) + C18 if A18 < m5 < B18 else 0
    hoh6 = ((m5 - A19) * D19) + C19 if A19 < m5 < B19 else 0
    hoh7 = ((m5 - A20) * D20) + C20 if A20 < m5 else 0

    # Return the combined HOH liability.
    return sum([hoh1, hoh2, hoh3, hoh4, hoh5, hoh6, hoh7])


def calculate_s(m5):
    """
    Calculate the federal liability for Single filers (S) based on the input m5.

    The liability is calculated in segments (s1 to s7) using thresholds and rates defined by cells A5-B5, A6-B6, etc.
    """
    s1 = (m5 * 0.1) + C5 if m5 < B5 else 0
    s2 = ((m5 - A6) * D6) + C6 if A6 < m5 < B6 else 0
    s3 = ((m5 - A7) * D7) + C7 if A7 < m5 < B7 else 0
    s4 = ((m5 - A8) * D8) + C8 if A8 < m5 < B8 else 0
    s5 = ((m5 - A9) * D9) + C9 if A9 < m5 < B9 else 0
    s6 = ((m5 - A10) * D10) + C10 if A10 < m5 < B10 else 0
    s7 = ((m5 - A11) * D11) + C11 if A11 < m5 else 0

    # Sum up the segments to get the total single filer liability.
    return sum([s1, s2, s3, s4, s5, s6, s7])


def get_rav_ratio(state: str, itc_rate: float):
    """
    Retrieve the revenue ratio for a given state and ITC rate.

    The revenue ratio used depends on the ITC rate (30, 40, or other)
    and whether the current month is before June or not.
    """
    if itc_rate == 30:
        rev_ratio = PREJULY[state][0] if datetime.now().month < 6 else POSTJULY[state][0]  # Uses first element
    elif itc_rate == 40:
        rev_ratio = PREJULY[state][1] if datetime.now().month < 6 else POSTJULY[state][1]  # Uses second element
    else:
        rev_ratio = PREJULY[state][2] if datetime.now().month < 6 else POSTJULY[state][2]  # Uses third element

    return rev_ratio


def get_tax_rate(state):
    """
    Return the tax rate for the given state as a decimal.

    The function chooses between the Pre-July or Post-July tax rate based on the current month.
    """
    return (PRE_JULY_TAX_RATE[state] if datetime.now().month < 6 else POST_JULY_TAX_RATE[state]) / 100
    # Alternatively, one could use a global TAX_RATE if defined:
    # return TAX_RATE[state] / 100


def get_acquisition_price_cash(state):
    """
    Get the cash ratio for acquisition price based on the state and ITC rate.

    For ITC rate 30, 40, or other values, the function selects the appropriate index from the
    Pre-July or Post-July dictionaries depending on the current month.
    """
    if itc_rate == 30:
        acquisition_price_cash = PRE_JULY_ACQUISITION_PRICE_CASH[state][0]  # Use first element for ITC 30
    elif itc_rate == 40:
        acquisition_price_cash = (PRE_JULY_ACQUISITION_PRICE_CASH[state][1] if datetime.now().month < 6
                                   else POST_JULY_ACQUISITION_PRICE_CASH[state][1])  # Use second element for ITC 40
    else:
        acquisition_price_cash = (PRE_JULY_ACQUISITION_PRICE_CASH[state][2] if datetime.now().month < 6
                                   else POST_JULY_ACQUISITION_PRICE_CASH[state][2])  # Use third element otherwise

    # Return the ratio as a decimal
    return acquisition_price_cash / 100


def get_fed_liability(state, M5):
    """
    Determine the federal tax liability based on filing status and the provided M5 value.

    It computes liabilities for MFJ, HOH, and Single filers (S) then returns the liability
    corresponding to the current family's filing status.
    """
    mfj = calculate_mfj(M5)
    hoh = calculate_hoh(M5)
    s = calculate_s(M5)

    fed_liabilities = {
        'MFJ': mfj,
        'HOH': hoh,
        'S': s,
    }

    return fed_liabilities[state]


def calculate_c34(solar_acquisition_price, data, M5):
    """
    Calculate the final federal tax liability adjustment (c34) based on the solar acquisition price,
    tax data, and the value M5.

    The function calculates an intermediate depreciation value (f16/f17) based on whether bonus depreciation is 100%.
    Then, it computes an adjusted value O5, uses it to determine liabilities for different filing statuses (MFJ, HOH, S),
    and then applies further adjustments based on the investment tax credit (itc_rate) and federal tax history.

    Finally, c34 is derived as the net difference between the tax components.
    """
    # Calculate adjusted depreciation values f16 and f17 based on solar acquisition price and adjustment factors.
    f16 = solar_acquisition_price * f13
    f17 = (solar_acquisition_price * f13 * f14) + (solar_acquisition_price * f13 * (1 - f14) * f18)
    c28 = f16 if bonus_depreciation_used == 100 else f17
    # O5 is the adjusted value after subtracting the depreciation component.
    O5 = M5 - c28

    # Recalculate MFJ liability segments for O5
    MFJ1 = (O5 * 0.1) + C23 if O5 < A23 else 0
    MFJ2 = ((O5 - A24) * D24) + C24 if B24 > O5 > A24 else 0
    MFJ3 = ((O5 - A25) * D25) + C25 if A25 < O5 < B25 else 0
    MFJ4 = ((O5 - A26) * D26) + C26 if A26 < O5 < B26 else 0
    MFJ5 = ((O5 - A27) * D27) + C27 if A27 < O5 < B27 else 0
    MFJ6 = ((O5 - A28) * D28) + C28 if A28 < O5 < B28 else 0
    MFJ7 = ((O5 - A29) * D29) + C29 if O5 > A29 else 0
    MFJ = sum([MFJ1, MFJ2, MFJ3, MFJ4, MFJ5, MFJ6, MFJ7])

    # Recalculate HOH liability segments for O5
    HOH1 = (O5 * 0.1) + C14 if O5 < A14 else 0
    HOH2 = ((O5 - A15) * D15) + C15 if A15 < O5 < B15 else 0
    HOH3 = ((O5 - A16) * D16) + C16 if A16 < O5 < B16 else 0
    HOH4 = ((O5 - A17) * D17) + C17 if A17 < O5 < B17 else 0
    HOH5 = ((O5 - A18) * D18) + C18 if A18 < O5 < B18 else 0
    HOH6 = ((O5 - A19) * D19) + C19 if A19 < O5 < B19 else 0
    HOH7 = ((O5 - A20) * D20) + C20 if A20 < O5 else 0
    HOH = sum([HOH1, HOH2, HOH3, HOH4, HOH5, HOH6, HOH7])

    # Recalculate Single filer (S) liability segments for O5
    S1 = (O5 * 0.1) + C5 if O5 < A5 else 0
    S2 = ((O5 - A6) * D6) + C6 if A6 < O5 < B6 else 0
    S3 = ((O5 - A7) * D7) + C7 if A7 < O5 < B7 else 0
    S4 = ((O5 - A8) * D8) + C8 if A8 < O5 < B8 else 0
    S5 = ((O5 - A9) * D9) + C9 if A9 < O5 < B9 else 0
    S6 = ((O5 - A10) * D10) + C10 if A10 < O5 < B10 else 0
    S7 = ((O5 - A11) * D11) + C11 if A11 < O5 else 0
    S = sum([S1, S2, S3, S4, S5, S6, S7])

    # Build a dictionary of updated federal liabilities by filing status.
    UPDATED_FED_LIABILITIES = {
        'MFJ': MFJ,
        'HOH': HOH,
        'S': S,
    }

    # Calculate the ITC component based on solar acquisition price.
    f40 = solar_acquisition_price * itc_rate / 100 if bonus_depreciation_used == 100 else solar_acquisition_price * itc_rate / 100
    # Get the federal liability based on the current family status.
    c30 = UPDATED_FED_LIABILITIES[FAMILY_STATUS]
    # Calculate c31: 75% of the amount exceeding $25,000 if c30 is above $25,000.
    c31 = (c30 - 25000) * 75 / 100 if c30 > 25000 else 0
    # c32 is the difference between the ITC component and c31, but not below zero.
    c32 = 0 if f40 - c31 < 0 else f40 - c31
    # Calculate c10 based on federal tax paid over the last three years.
    c10 = calculate_c10(float(data['fed_tax_2023']), float(data['fed_tax_2022']), float(data['fed_tax_2021']))
    c33 = c10
    # Determine final tax liability adjustment (c34) based on the computed values.
    c34 = c33 - c32 if c32 > 0 else c31 - f40

    # Return the absolute value of c34.
    return abs(c34)


def calculate_c6(m5):
    """
    Calculate the overall federal tax liability (c6) for the current filing status based on m5.

    This function computes MFJ, HOH, and Single liabilities separately using the same segmented logic
    as in earlier functions, then returns the liability corresponding to the current FAMILY_STATUS.
    """
    mfj1 = (m5 * 0.1) + C23 if m5 < B23 else 0
    mfj2 = ((m5 - A24) * D24) + C24 if B24 > m5 > A24 else 0
    mfj3 = ((m5 - A25) * D25) + C25 if A25 < m5 < B25 else 0
    mfj4 = ((m5 - A26) * D26) + C26 if A26 < m5 < B26 else 0
    mfj5 = ((m5 - A27) * D27) + C27 if A27 < m5 < B27 else 0
    mfj6 = ((m5 - A28) * D28) + C28 if A28 < m5 < B28 else 0
    mfj7 = ((m5 - A29) * D29) + C29 if m5 > A29 else 0
    mfj = sum([mfj1, mfj2, mfj3, mfj4, mfj5, mfj6, mfj7])

    hoh1 = (m5 * 0.1) + C14 if m5 < B14 else 0
    hoh2 = ((m5 - A15) * D15) + C15 if A15 < m5 < B15 else 0
    hoh3 = ((m5 - A16) * D16) + C16 if A16 < m5 < B16 else 0
    hoh4 = ((m5 - A17) * D17) + C17 if A17 < m5 < B17 else 0
    hoh5 = ((m5 - A18) * D18) + C18 if A18 < m5 < B18 else 0
    hoh6 = ((m5 - A19) * D19) + C19 if A19 < m5 < B19 else 0
    hoh7 = ((m5 - A20) * D20) + C20 if A20 < m5 else 0
    hoh = sum([hoh1, hoh2, hoh3, hoh4, hoh5, hoh6, hoh7])

    s1 = (m5 * 0.1) + C5 if m5 < B5 else 0
    s2 = ((m5 - A6) * D6) + C6 if A6 < m5 < B6 else 0
    s3 = ((m5 - A7) * D7) + C7 if A7 < m5 < B7 else 0
    s4 = ((m5 - A8) * D8) + C8 if A8 < m5 < B8 else 0
    s5 = ((m5 - A9) * D9) + C9 if A9 < m5 < B9 else 0
    s6 = ((m5 - A10) * D10) + C10 if A10 < m5 < B10 else 0
    s7 = ((m5 - A11) * D11) + C11 if A11 < m5 else 0
    s = sum([s1, s2, s3, s4, s5, s6, s7])

    fed_liabilities = {
        'MFJ': mfj,
        'HOH': hoh,
        'S': s,
    }

    return fed_liabilities[FAMILY_STATUS]


def calculate_c10(c7, c8, c9):
    """
    Calculate an aggregate federal tax component (c10) using values from the last three years.

    For each year's value, if it exceeds 25000, subtract 25000; then take 75% of the total.
    """
    def calculate_individual(value):
        return value - 25000 if value > 25000 else 0

    total = (calculate_individual(c7) + calculate_individual(c8) + calculate_individual(c9)) * 0.75
    return total


def generate_message(**kwargs):
    """
    Generate a formatted message string based on provided keyword arguments.

    If the type is 'earned_income' or 'urgent', the message includes detailed financial data.
    Otherwise, it includes only basic user information.
    """
    if kwargs['type'] in ('earned_income', 'urgent'):
        msg = f"""
                User email: {kwargs['email']}
                User full name: {kwargs['name']}
                Selected income type: {kwargs['income_type']}
                User state: {kwargs['state']}
                2024 AGI: ${"{:,}".format(kwargs['agi'])}
                2023 Fed Tax Paid: ${"{:,}".format(kwargs['fed_tax_2023'])}
                2022 Fed Tax Paid: ${"{:,}".format(kwargs['fed_tax_2022'])}
                2021 Fed Tax Paid: ${"{:,}".format(kwargs['fed_tax_2021'])}
              """
    else:
        msg = f"""
                User email: {kwargs['email']}
                User full name: {kwargs['name']}
                Selected income type: {kwargs['income_type']}
               """
    return msg


def pmt(rate, nper, pv, fv=0, when='end'):
    """
    Calculate the payment per period for a loan or investment with principal plus interest.

    Parameters:
        rate : float
            Interest rate per period (e.g., 0.05 for 5% annual interest).
        nper : int
            Total number of periods (e.g., 30*12 for a 30-year monthly loan).
        pv : float
            Present value (e.g., 100000 for a $100,000 loan).
        fv : float, optional
            Future value (default is 0).
        when : {'begin', 'end'}, optional
            Specifies when payments are made (default is 'end' of period).

    Returns:
        float
            Payment amount per period. Payments are negative if you are paying out money.

    Notes:
        This function follows the convention where cash inflows (pv) are positive and outflows (pmt) are negative.
    """
    # Convert rate to float and check for zero rate.
    rate = float(rate)
    if rate == 0:
        return -(pv + fv) / nper

    # Check that the number of periods is positive.
    if nper <= 0:
        raise ValueError("Number of periods must be positive")

    # Ensure payment timing is valid.
    when = when.lower()
    if when not in {'begin', 'end'}:
        raise ValueError("Payment timing must be 'begin' or 'end'")
    due = 1 if when == 'begin' else 0

    # Calculate a temporary variable for compound interest.
    temp = (1 + rate) ** nper
    mask = (temp != 1)

    # Use numpy.where to handle potential division by zero.
    z = np.where(mask, (1 + rate * due) * (temp - 1) / (rate * temp), nper)
    payment = -(pv + fv / temp) / z

    return float(payment)


# The following function to send emails is commented out.
# It uses Django's send_mail function to dispatch an email with a given subject and message.
# Uncomment and adjust as necessary when integrating email functionality.

# def send_emails(subject, message, recipient_list):
#     from_email = settings.EMAIL_HOST_USER
#
#     try:
#         send_mail(subject, message, from_email, recipient_list)
#         print('Emails sent successfully.')
#     except Exception as e:
#         print(f'Failed to send emails: {e}')

# %% [markdown]
# # **Views.py**

# %%
import numpy as np
from rest_framework import status
from rest_framework.response import Response
from rest_framework.views import APIView
from scipy.optimize import minimize
from .celery import send_emails         # Asynchronous email sending via Celery
from .serializers import MultiplySerializer
from .utils import *                    # Import all helper functions and constants

# =============================================================================
# CalculateSolarView
# =============================================================================
class CalculateSolarView(APIView):
    """
    API endpoint that calculates solar financing and tax benefit metrics.

    It uses input data (e.g., AGI, state, optional solar acquisition price) to compute:
      - Solar acquisition price (full system cost based on a cash ratio)
      - Depreciation, ITC, federal liability, and year-by-year cash flows/returns
      - Environmental impact estimates (carbon dioxide, trees, etc.)
    """

    @staticmethod
    def post(request):
        # Validate and deserialize the incoming data using the serializer.
        serializer = MultiplySerializer(data=request.data)
        if serializer.is_valid():
            data = serializer.validated_data

            # Retrieve the state from the input.
            state = data.get('state')

            # M5 represents the Adjusted Gross Income (AGI) used in tax calculations.
            M5 = float(data['agi'])

            # If the solar acquisition price is not provided, determine it via optimization.
            if 'solar_acquisition_price' not in data:
                # Generate a notification message (for earned income type) and send it.
                message = generate_message(**data, type='earned_income')
                send_emails.delay("Solar Calculator", message, EMAILS)

                # Define a constraint function for optimization.
                # The constraint ensures that the cash portion of the acquisition price (solar_acquisition_price * acquisition_price_cash)
                # is at least 150,000.
                def constraint(solar_acquisition_price):
                    return solar_acquisition_price * get_acquisition_price_cash(state) - 150000

                initial_guess = 1500000  # Initial guess for the solar acquisition price.
                constraints = [{'type': 'ineq', 'fun': constraint}]

                # Use SciPy's minimize function to find the solar acquisition price
                # that minimizes the square of the federal tax adjustment (calculate_c34).
                result = minimize(lambda x: calculate_c34(x, data, M5) ** 2,
                                  initial_guess, constraints=constraints)
                solar_acquisition_price = result.x[0]
            else:
                # If provided, convert the cash outlay to the full solar acquisition price using the state cash ratio.
                total_cash_out_pocket = float(data.get("solar_acquisition_price"))
                acquisition_price_cash = get_acquisition_price_cash(state)
                solar_acquisition_price = total_cash_out_pocket / acquisition_price_cash

            # -------------------------------------------------------------------------
            # Compute intermediate depreciation factors:
            # f16 adjusts the acquisition price for ITC effects (f13 factor)
            # f17 incorporates bonus depreciation (using bonus percentage f14 and the remaining basis f18)
            # -------------------------------------------------------------------------
            f16 = solar_acquisition_price * f13
            f17 = (solar_acquisition_price * f13 * f14) + (solar_acquisition_price * f13 * (1 - f14) * f18)

            # g15 is a multiplier derived from f13, g18, and a 40% constant factor.
            g15 = f13 * g18 * 40 / 100
            g17 = solar_acquisition_price * g15

            # Get the overall federal liability based on the filing status (FAMILY_STATUS) and AGI.
            fed_liability = get_fed_liability(FAMILY_STATUS, M5)

            # Retrieve state-specific revenue ratio and tax rate.
            rev_ratio = get_rav_ratio(state, itc_rate)
            tax_rate = get_tax_rate(state)  # (as a decimal)

            # Re-get the cash ratio for acquisition price for the state.
            acquisition_price_cash = get_acquisition_price_cash(state)

            # -------------------------------------------------------------------------
            # Project revenue/depreciation values over multiple years using an annual escalator.
            # The variables ac4, ad4, ae4, etc., represent successive year adjustments.
            # -------------------------------------------------------------------------
            ab4 = 0
            ac4 = solar_acquisition_price * rev_ratio / 100
            ad4 = ac4 * (1 + annual_escalator)
            ae4 = ad4 * (1 + annual_escalator)
            af4 = ae4 * (1 + annual_escalator)
            ag4 = af4 * (1 + annual_escalator)
            ah4 = ag4 * (1 + annual_escalator)
            ai4 = ah4 * (1 + annual_escalator)
            aj4 = ai4 * (1 + annual_escalator)
            ak4 = aj4 * (1 + annual_escalator)
            al4 = ak4 * (1 + annual_escalator)
            am4 = al4 * (1 + annual_escalator)
            an4 = am4 * (1 + annual_escalator)
            ao4 = an4 * (1 + annual_escalator)
            ap4 = ao4 * (1 + annual_escalator)
            aq4 = ap4 * (1 + annual_escalator)
            ar4 = aq4 * (1 + annual_escalator)
            as4 = ar4 * (1 + annual_escalator)
            at4 = as4 * (1 + annual_escalator)
            au4 = at4 * (1 + annual_escalator)
            av4 = au4 * (1 + annual_escalator)
            aw4 = av4 * (1 + annual_escalator)
            ax4 = aw4 * (1 + annual_escalator)
            ay4 = ax4 * (1 + annual_escalator)
            az4 = ay4 * (1 + annual_escalator)
            ba4 = az4 * (1 + annual_escalator)
            bb4 = ba4 * (1 + annual_escalator)
            bc4 = bb4 * (1 + annual_escalator)
            bd4 = bc4 * (1 + annual_escalator)
            be4 = bd4 * (1 + annual_escalator)
            bf4 = be4 * (1 + annual_escalator)
            bg4 = bf4 * (1 + annual_escalator)
            bh4 = bg4 * (1 + annual_escalator)
            bi4 = bh4 * (1 + annual_escalator)
            bj4 = bi4 * (1 + annual_escalator)
            bk4 = bj4 * (1 + annual_escalator)

            # -------------------------------------------------------------------------
            # Calculate the cash component of the solar acquisition price.
            # c23 = portion paid in cash; c24 = financed portion.
            # -------------------------------------------------------------------------
            c23 = solar_acquisition_price * acquisition_price_cash
            c24 = solar_acquisition_price - c23

            # Calculate a periodic payment using the PMT function for the financed portion.
            g12 = pmt(f12, i12, c24)

            # -------------------------------------------------------------------------
            # Determine additional adjustments for a series of periods.
            # Here, each variable (ac7, ad7, …, bk7) is set to a periodic payment if a certain index threshold is not exceeded.
            # The variables ac2, ad2, etc. are assumed to be part of the imported utilities.
            # -------------------------------------------------------------------------
            ac7 = 0 if ac2 > i12 else g12
            ad7 = 0 if ad2 > i12 else g12
            ae7 = 0 if ae2 > i12 else g12
            af7 = 0 if af2 > i12 else g12
            ag7 = 0 if ag2 > i12 else g12
            ah7 = 0 if ah2 > i12 else g12
            ai7 = 0 if ai2 > i12 else g12
            aj7 = 0 if aj2 > i12 else g12
            ak7 = 0 if ak2 > i12 else g12
            al7 = 0 if al2 > i12 else g12
            am7 = 0 if am2 > i12 else g12
            an7 = 0 if an2 > i12 else g12
            ao7 = 0 if ao2 > i12 else g12
            ap7 = 0 if ap2 > i12 else g12
            aq7 = 0 if aq2 > i12 else g12
            ar7 = 0 if ar2 > i12 else g12
            as7 = 0 if as2 > i12 else g12
            at7 = 0 if at2 > i12 else g12
            au7 = 0 if au2 > i12 else g12
            av7 = 0 if av2 > i12 else g12
            aw7 = 0 if aw2 > i12 else g12
            ax7 = 0 if ax2 > i12 else g12
            ay7 = 0 if ay2 > i12 else g12
            az7 = 0 if az2 > i12 else g12
            ba7 = 0 if ba2 > i12 else g12
            bb7 = 0 if bb2 > i12 else g12
            bc7 = 0 if bc2 > i12 else g12
            bd7 = 0 if bd2 > i12 else g12
            be7 = 0 if be2 > i12 else g12
            bf7 = 0 if bf2 > i12 else g12
            bg7 = 0 if bg2 > i12 else g12
            bh7 = 0 if bh2 > i12 else g12
            bi7 = 0 if bi2 > i12 else g12
            bj7 = 0 if bj2 > i12 else g12
            bk7 = 0 if bk2 > i12 else g12

            # Recalculate the cash component values (c23 and c24) from the acquisition price.
            c23 = solar_acquisition_price * acquisition_price_cash
            c24 = solar_acquisition_price - c23

            # The following commented lines hint at further adjustments for depreciation,
            # which are implemented later by calculating ac5, ac6, and so on.
            # ab5 = -ab4 * c24
            # ab6 = ab4 + ab5
            # ab7 = -c24 * f12
            # ab8 = ab6 + ab7

            # Calculate state tax adjustment for revenue.
            ac5 = -ac4 * c14
            ac6 = ac4 + ac5
            ac8 = ac6 + ac7

            # Compute two alternative Year 1 depreciation/return amounts:
            # ab42 for 100% bonus depreciation and ab53 for the alternative scenario.
            ab42 = sum([f16 * c17, solar_acquisition_price * itc_rate / 100,
                        solar_acquisition_price * f18 * tax_rate, ac8])
            ab53 = sum([f17 * c17, solar_acquisition_price * itc_rate / 100,
                        solar_acquisition_price * f18 * tax_rate, ac8])

            # Set up intermediate variables for adjustment ratios.
            aa48 = -c23
            aa53 = aa48
            aa42 = aa53
            ab55 = ab53 / -aa53
            ab44 = ab42 / -aa42

            total_cash_out_of_pocket = solar_acquisition_price * acquisition_price_cash

            # Further adjustments for Year 1 federal tax components.
            h17 = solar_acquisition_price * h15
            ad49 = g17 * c17

            ad5 = -ad4 * c14
            ad6 = ad4 + ad5
            ad8 = ad6 + ad7

            ad50 = 0
            ad51 = solar_acquisition_price * g18 * tax_rate
            ad52 = ad8

            ad53 = sum([ad49, ad50, ad51, ad52])

            ad38 = ad39 = 0
            ad40 = solar_acquisition_price * g18 * tax_rate
            ad41 = ad8

            ad42 = sum([ad38, ad39, ad40, ad41])

            ae38 = 0
            ae39 = 0
            ae40 = solar_acquisition_price * h18 * tax_rate
            ae5 = -ae4 * c14
            ae6 = ae4 + ae5
            ae8 = ae6 + ae7
            ae41 = ae8

            i17 = solar_acquisition_price * i15

            ae49 = h17 * c17
            ae50 = 0
            ae51 = solar_acquisition_price * h18 * tax_rate
            ae52 = ae8

            ae42 = sum([ae38, ae39, ae40, ae41])
            ae53 = sum([ae49, ae50, ae51, ae52])

            af38 = af39 = 0
            af40 = solar_acquisition_price * i18 * tax_rate
            af5 = -af4 * c14
            af6 = af4 + af5
            af8 = af6 + af7
            af41 = af8

            j15 = 0.4 * f13 * j18
            j17 = solar_acquisition_price * j15
            af49 = c17 * i17
            af50 = 0
            af51 = solar_acquisition_price * j18 * tax_rate
            af52 = af8

            af42 = sum([af38, af39, af40, af41])
            af53 = sum([af49, af50, af51, af52])

            ag38 = ag39 = 0
            ag40 = solar_acquisition_price * j18 * tax_rate
            ag4 = af4 * (1 + annual_escalator)
            ag5 = -ag4 * c14
            ag6 = ag4 + ag5
            ag8 = ag6 + ag7
            ag41 = ag8

            # Recompute ag8 as an adjusted value with escalator and state tax adjustments.
            ag8 = af4 * (1 + annual_escalator) + (-ag4 * c14) + ag7
            ag42 = sum([ag38, ag39, ag40, ag41])

            k15 = 0.4 * f13 * k18
            k17 = solar_acquisition_price * k15
            ag49 = j17 * c17
            ag50 = 0
            ag51 = solar_acquisition_price * j18 * tax_rate
            ag52 = ag8
            ag53 = sum([ag49, ag50, ag51, ag52])

            ac38 = ac39 = 0
            ac40 = solar_acquisition_price * g18 * tax_rate
            ac41 = ac8
            ac42 = sum([ac38, ac39, ac40, ac41])

            g15 = 0.4 * f13 * g18  # Derived multiplier (e.g., 32 * 0.8 * 0.4)
            g17 = solar_acquisition_price * g15
            ac49 = g17 * c17
            ac50 = 0
            ac51 = solar_acquisition_price * g18 * tax_rate
            ac52 = ac8
            ac53 = sum([ac49, ac50, ac51, ac52])

            ab38 = f16 * c17
            ab49 = f17 * c17

            ab39 = solar_acquisition_price * itc_rate / 100
            ab40 = solar_acquisition_price * f18 * tax_rate
            ab41 = ac8
            ab50 = ab39
            ab51 = solar_acquisition_price * f18 * tax_rate
            ab52 = ac8

            # Choose Year 1 return based on bonus depreciation usage.
            f43 = ab42 if bonus_depreciation_used == 100 else ab53
            g43 = ac42 if bonus_depreciation_used == 100 else ac53
            h43 = ad42 if bonus_depreciation_used == 100 else ad53
            i43 = ae42 if bonus_depreciation_used == 100 else ae53
            j43 = af42 if bonus_depreciation_used == 100 else af53
            k43 = ag42 if bonus_depreciation_used == 100 else ag53

            ab43 = ab42 + aa42
            ab54 = ab53 + aa53
            ac43 = ac42 + ab43
            ac54 = ac53 + ab54
            ad43 = ad42 + ab43
            ad54 = ad53 + ab54
            ae43 = ae42 + ad43
            ae54 = ae53 + ad54
            af43 = af42 + ae43
            af54 = af53 + ae54
            ag43 = ag42 + af43
            ag54 = ag53 + af54
            ac44 = sum([ab42, ac42]) / -aa53
            ac55 = sum([ab53, ac53]) / -aa53
            ad44 = sum([ab42, ac42, ad42]) / -aa53
            ad55 = sum([ab53, ac53, ad53]) / -aa53
            ae44 = sum([ab42, ac42, ad42, ae42]) / -aa53
            ae55 = sum([ab53, ac53, ad53, ae53]) / -aa53
            af44 = sum([ab42, ac42, ad42, ae42, af42]) / -aa53
            af55 = sum([ab53, ac53, ad53, ae53, af53]) / -aa53
            ag44 = sum([ab42, ac42, ad42, ae42, af42, ag42]) / -aa53
            ag55 = sum([ab53, ac53, ad53, ae53, af53, ag53]) / -aa53

            c6 = calculate_c6(M5)

            # Compute Year 1 federal returns (f39 and f41) based on bonus depreciation usage.
            f39 = ab38 if bonus_depreciation_used == 100 else ab49
            g39 = ad38 if bonus_depreciation_used == 100 else ad49
            h39 = ae38 if bonus_depreciation_used == 100 else ae49
            i39 = af38 if bonus_depreciation_used == 100 else af49
            j39 = ag38 if bonus_depreciation_used == 100 else ag49

            f41 = ab40 if bonus_depreciation_used == 100 else ab51
            g41 = ad40 if bonus_depreciation_used == 100 else ad51
            h41 = ae40 if bonus_depreciation_used == 100 else ae51
            i41 = af40 if bonus_depreciation_used == 100 else af51
            j41 = ag40 if bonus_depreciation_used == 100 else ag51

            # Adjust cash flow components for subsequent years using escalator and state tax factors.
            ag8 = ag4 + (-ag4 * c14) + ag7
            ah8 = ah4 + (-ah4 * c14) + ah7
            ai8 = ai4 + (-ai4 * c14) + ai7
            aj8 = aj4 + (-aj4 * c14) + aj7
            ak8 = ak4 + (-ak4 * c14) + ak7
            al8 = al4 + (-al4 * c14) + al7
            am8 = am4 + (-am4 * c14) + am7
            an8 = an4 + (-an4 * c14) + an7
            ao8 = ao4 + (-ao4 * c14) + ao7
            ap8 = ap4 + (-ap4 * c14) + ap7
            aq8 = aq4 + (-aq4 * c14) + aq7
            ar8 = ar4 + (-ar4 * c14) + ar7
            as8 = as4 + (-as4 * c14) + as7
            at8 = at4 + (-at4 * c14) + at7
            au8 = au4 + (-au4 * c14) + au7
            av8 = av4 + (-av4 * c14) + av7
            aw8 = aw4 + (-aw4 * c14) + aw7
            ax8 = ax4 + (-ax4 * c14) + ax7
            ay8 = ay4 + (-ay4 * c14) + ay7
            az8 = az4 + (-az4 * c14) + az7
            ba8 = ba4 + (-ba4 * c14) + ba7
            bb8 = bb4 + (-bb4 * c14) + bb7
            bc8 = bc4 + (-bc4 * c14) + bc7
            bd8 = bd4 + (-bd4 * c14) + bd7
            be8 = be4 + (-be4 * c14) + be7
            bf8 = bf4 + (-bf4 * c14) + bf7
            bg8 = bg4 + (-bg4 * c14) + bg7
            bh8 = bh4 + (-bh4 * c14) + bh7
            bi8 = bi4 + (-bi4 * c14) + bi7
            bj8 = bj4 + (-bj4 * c14) + bj7
            bk8 = bk4 + (-bk4 * c14) + bk7

            # Additional adjustments for year 7 calculations.
            ah38 = 0
            ah39 = 0
            ah40 = solar_acquisition_price * k18 * tax_rate
            ah41 = ah8

            ah42 = ah38 + ah39 + ah40 + ah41
            ah43 = ah42 + ag43
            ah44 = sum([ab42, ac42, ad42, ae42, af42, ag42, ah42]) / -aa53

            ah49 = k17 * c17
            ah51 = solar_acquisition_price * k18 * tax_rate
            ah52 = ah8
            ah53 = ah49 + ah51 + ah52
            ah54 = ah53 + ag54
            ag55 = sum([ab53, ac53, ad53, ae53, af53, ag53, ah53]) / -aa53

            k39 = ah38 if bonus_depreciation_used == 100 else ah49
            k41 = ah40 if bonus_depreciation_used == 100 else ah51

            f42 = ac8
            g42 = ad8
            h42 = ae8
            i42 = af8
            j42 = ag8
            k42 = ah8

            # For Year 1 ITC, select appropriate value based on bonus depreciation flag.
            f40 = ab39 if bonus_depreciation_used == 100 else ab50
            g40 = 0
            h40 = 0
            i40 = 0
            j40 = 0
            k40 = 0
            l40 = 0
            l39 = 0
            l41 = 0

            # Sum up components to form Year 1 return values.
            f43 = sum([f39, f40, f41, f42])
            g43 = sum([g39, g40, g41, g42])
            h43 = sum([h39, h40, h41, h42])
            i43 = sum([i39, i40, i41, i42])
            j43 = sum([j39, j40, j41, j42])
            k43 = sum([k39, k40, k41, k42])
            e43 = aa42 if bonus_depreciation_used == 100 else aa53

            # Compute net benefits and ROI for subsequent years.
            f44 = e43 + f43
            g44 = f44 + g43
            h44 = g44 + h43
            i44 = h44 + i43
            j44 = i44 + j43
            k44 = j44 + k43

            # Calculate Year 7 cash flow as the residual difference.
            l42 = sum([ac8, ad8, ae8, af8, ag8, ah8, ai8, aj8, ak8, al8, am8, an8, ao8, ap8, aq8, ar8, as8, at8, au8, av8, aw8, ax8, ay8, az8, ba8, bb8, bc8, bd8, be8, bf8, bg8, bh8, bi8, bj8, bk8, bl8]) - \
                  sum([year_1_cash_flow, year_2_cash_flow, year_3_cash_flow, year_4_cash_flow, year_5_cash_flow, year_6_cash_flow])

            l43 = sum([l39, l40, l41, l42])
            l44 = k44 + l43

            # Compute ROI percentages for each year segment.
            f45 = abs(f43 / e43)
            g45 = abs((f43 + g43) / e43)
            h45 = abs((f43 + g43 + h43) / e43)
            i45 = abs((f43 + g43 + h43 + i43) / e43)
            j45 = abs((f43 + g43 + h43 + i43 + j43) / e43)
            k45 = abs((f43 + g43 + h43 + i43 + j43 + k43) / e43)
            l45 = abs((f43 + g43 + h43 + i43 + j43 + k43 + l43) / e43)

            c44 = l45

            # Total 6-year ROI and gross benefit calculations.
            total_6_year_roi = sum([f43, g43, h43, i43, j43, k43])
            total_gross_benefit = l44 + total_cash_out_of_pocket

            # -------------------------------------------------------------------------
            # Build the response dictionary. The keys (x1, x2, etc.) represent output metrics:
            #   x1: Overall federal liability.
            #   x2: Solar acquisition price.
            #   x3: ITC benefit component.
            #   x4, x5, x6: Various ROI percentages.
            #   Total cash outlay, yearly amounts, net returns, and environmental impacts.
            # -------------------------------------------------------------------------
            response = {
                'x11': c23,  # Cash component of acquisition price
                'x12': c24,  # Financed portion of acquisition price
                'x2': solar_acquisition_price,
                'x13': round(tax_rate * 100),
                'x1': c6,
                'x3': ab39 if bonus_depreciation_used == 100 else ab50,
                'x4': f39 + f41,
                'x5': ab43 if bonus_depreciation_used == 100 else ab54,
                'x6': ab44 * 100 if bonus_depreciation_used == 100 else ab55 * 100,
                'total_cash_out_of_pocket': total_cash_out_of_pocket,
                'total_gross_benefit': total_gross_benefit,
                'year_1_amount': ab42 if bonus_depreciation_used == 100 else ab53,
                'year_1_percent': ab44 * 100 if bonus_depreciation_used == 100 else ab55 * 100,
                'total_6_year_r': total_6_year_roi,
                'total_6_year_net_r': total_6_year_roi - total_cash_out_of_pocket,
                'full_6_year_percent': ag44 * 100 if bonus_depreciation_used == 100 else ag55 * 100,
                'full_return': c44,
                'year_1_fed': f39,
                'year_2_fed': g39,
                'year_3_fed': h39,
                'year_4_fed': i39,
                'year_5_fed': j39,
                'year_6_fed': k39,
                'year_7_fed': l39,
                'year_1_itc': f40,
                'year_2_itc': g40,
                'year_3_itc': h40,
                'year_4_itc': i40,
                'year_5_itc': j40,
                'year_6_itc': k40,
                'year_7_itc': l40,
                'year_1_st': f41,
                'year_2_st': g41,
                'year_3_st': h41,
                'year_4_st': i41,
                'year_5_st': j41,
                'year_6_st': k41,
                'year_7_st': l41,
                'year_1_cash_flow': f42,
                'year_2_cash_flow': g42,
                'year_3_cash_flow': h42,
                'year_4_cash_flow': i42,
                'year_5_cash_flow': j42,
                'year_6_cash_flow': k42,
                'year_7_cash_flow': l42,
                'year_1_net_benefit': f44,
                'year_2_net_benefit': g44,
                'year_3_net_benefit': h44,
                'year_4_net_benefit': i44,
                'year_5_net_benefit': j44,
                'year_6_net_benefit': k44,
                'year_7_net_benefit': l44,
                'year_1_roi': f45 * 100,
                'year_2_roi': g45 * 100,
                'year_3_roi': h45 * 100,
                'year_4_roi': i45 * 100,
                'year_5_roi': j45 * 100,
                'year_6_roi': k45 * 100,
                'year_7_roi': l45 * 100,
                'year_7_$': l43,
                'year_1_$': f43,
                'year_2_$': g43,
                'year_3_$': h43,
                'year_4_$': i43,
                'year_5_$': j43,
                'year_6_$': k43,
                'carbon_dioxide': solar_acquisition_price / 3 / 1000 * f6,
                'tree': solar_acquisition_price / 3 / 1000 * f7,
                'coal': solar_acquisition_price / 3 / 1000 * f8,
                'vehicle': solar_acquisition_price / 3 / 1000 * f9
            }

            # Helper function to format numbers with commas.
            def format_number_with_commas(number):
                rounded_number = round(number)
                return f"{rounded_number:,}"

            # Format each output value for better readability.
            response = {k: format_number_with_commas(round(v)) for k, v in response.items()}

            # Return the final response, serialized.
            return Response(MultiplySerializer(response).data)
        # If the serializer is invalid, return errors with a 400 status code.
        return Response(serializer.errors, status=status.HTTP_400_BAD_REQUEST)


# =============================================================================
# CalculateSliderView
# =============================================================================
class CalculateSliderView(APIView):
    """
    API endpoint that calculates solar financing metrics using a provided slider input.

    This view assumes the solar acquisition price is provided directly (as total cash outlay)
    and computes many of the same metrics as CalculateSolarView.
    """
    def post(self, request):
        serializer = MultiplySerializer(data=request.data)
        if serializer.is_valid():
            data = serializer.validated_data

            # Optionally, generate and send an email notification.
            # message = generate_message(**data)
            # send_emails.delay("Solar Calculator", message, EMAILS)

            total_cash_out_pocket = float(data.get("solar_acquisition_price"))
            state = data.get('state')
            acquisition_price_cash = get_acquisition_price_cash(state)
            solar_acquisition_price = total_cash_out_pocket / acquisition_price_cash

            M5 = data.get("agi")
            acquisition_price_cash = get_acquisition_price_cash(state)
            tax_rate = get_tax_rate(state)  # (as a decimal)
            rev_ratio = get_rav_ratio(state, itc_rate)
            c6 = calculate_c6(M5)

            # Recalculate intermediate depreciation factors.
            f16 = solar_acquisition_price * f13
            f17 = (solar_acquisition_price * f13 * f14) + (solar_acquisition_price * f13 * (1 - f14) * f18)

            ab38 = f16 * c17
            ab49 = f17 * c17

            ab39 = solar_acquisition_price * itc_rate / 100
            ab40 = solar_acquisition_price * f18 * tax_rate
            ab50 = ab39
            ab51 = solar_acquisition_price * f18 * tax_rate

            f39 = ab38 if bonus_depreciation_used == 100 else ab49
            f41 = ab40 if bonus_depreciation_used == 100 else ab51

            ab4 = solar_acquisition_price * rev_ratio / 100
            ab5 = -ab4 * c14
            c23 = solar_acquisition_price * acquisition_price_cash
            c24 = solar_acquisition_price - c23
            ab6 = ab4 + ab5
            ab7 = -c24 * f12
            ab8 = ab6 + ab7
            ab42 = sum([f16 * c17, solar_acquisition_price * itc_rate / 100,
                        solar_acquisition_price * f18 * tax_rate, ab8])
            ab53 = sum([f17 * c17, solar_acquisition_price * itc_rate / 100,
                        solar_acquisition_price * f18 * tax_rate, ab8])

            aa48 = -c23
            aa53 = aa48
            aa42 = aa53
            ab55 = ab53 / -aa53
            ab44 = ab42 / -aa42

            ab43 = ab42 + aa42
            ab54 = ab53 + aa53

            ac4 = solar_acquisition_price * rev_ratio

            total_cash_out_of_pocket = solar_acquisition_price * acquisition_price_cash
            ad4 = ac4 * (1 + annual_escalator)
            ae4 = ad4 * (1 + annual_escalator)

            af38 = af39 = 0
            af40 = solar_acquisition_price * j18 * tax_rate
            af7 = ab7
            af4 = ae4 * (1 + annual_escalator)
            af5 = -af4 * c14
            af6 = af4 + af5
            af8 = af6 + af7
            af41 = af8

            af8 = ae4 * (1 + annual_escalator) + (-af4 * c14) + af7

            j15 = 0.4 * f13 * j18
            j17 = solar_acquisition_price * j15
            af49 = c17 * j17
            af50 = 0
            af51 = solar_acquisition_price * j18 * tax_rate
            af52 = af8

            af42 = sum([af38, af39, af40, af41])
            af53 = sum([af49, af50, af51, af52])

            ag38 = ag39 = 0
            ag40 = solar_acquisition_price * k18 * tax_rate
            ag7 = ab7
            ag4 = af4 * (1 + annual_escalator)
            ag5 = -ag4 * c14
            ag6 = ag4 + ag5
            ag8 = ag6 + ag7
            ag41 = ag8

            ag42 = sum([ag38, ag39, ag40, ag41])

            k15 = 0.4 * f13 * k18
            k17 = solar_acquisition_price * k15
            ag49 = k17 * c17
            ag50 = 0
            ag51 = solar_acquisition_price * j18 * tax_rate
            ag52 = ag8
            ag53 = sum([ag49, ag50, ag51, ag52])

            ac38 = ac39 = 0
            g18 = 32 / 100
            ac40 = solar_acquisition_price * g18 * tax_rate
            ac5 = -ac4 * c14
            ac6 = ac4 + ac5
            ac7 = ab7
            ac8 = ac6 + ac7
            ac41 = ac8
            ac42 = sum([ac38, ac39, ac40, ac41])

            g15 = 0.4 * f13 * g18  # Derived multiplier for revenue
            g17 = solar_acquisition_price * g15
            ac49 = g17 * c17
            ac50 = 0
            ac51 = solar_acquisition_price * g18 * tax_rate
            ac52 = ac8
            ac53 = sum([ac49, ac50, ac51, ac52])

            ab39 = solar_acquisition_price * itc_rate / 100
            ab50 = ab39

            ad38 = ad39 = 0
            ad40 = solar_acquisition_price * h18 * tax_rate

            ad4 = ac4 * (1 + annual_escalator)
            ad5 = -ad4 * c14
            ad7 = ab7
            ad6 = ad4 + ad5
            ad8 = ad6 + ad7

            ad41 = ad8

            ad50 = 0
            ad51 = solar_acquisition_price * h18 * tax_rate
            ad52 = ad8
            h17 = solar_acquisition_price * h15
            ad49 = g17 * c17

            ad53 = sum([ad49, ad50, ad51, ad52])
            ad42 = sum([ad38, ad39, ad40, ad41])

            i17 = solar_acquisition_price * i15
            ae4 = ad4 * (1 + annual_escalator)
            ae5 = -ae4 * c14
            ae6 = ae4 + ae5
            ae7 = ab7
            ae8 = ae6 + ae7
            ae49 = h17 * c17
            ae50 = 0
            ae51 = solar_acquisition_price * i18 * tax_rate
            ae52 = ae8

            ae38 = 0
            ae39 = 0
            ae40 = solar_acquisition_price * i18 * tax_rate
            ae4 = ad4 * (1 + annual_escalator)
            ae5 = -ae4 * c14
            ae6 = ae4 + ae5
            ae7 = ab7
            ae8 = ae6 + ae7
            ae41 = ae8

            ae42 = sum([ae38, ae39, ae40, ae41])
            ae53 = sum([ae49, ae50, ae51, ae52])

            f43 = ab42 if bonus_depreciation_used == 100 else ab53
            g43 = ac42 if bonus_depreciation_used == 100 else ac53
            h43 = ad42 if bonus_depreciation_used == 100 else ad53
            i43 = ae42 if bonus_depreciation_used == 100 else ae53
            j43 = af42 if bonus_depreciation_used == 100 else af53
            k43 = ag42 if bonus_depreciation_used == 100 else ag53

            total_6_year_roi = sum([f43, g43, h43, i43, j43, k43])
            ab43 = ab42 + aa42
            ab54 = ab53 + aa53
            ac43 = ac42 + ab43
            ac54 = ac53 + ab54
            ad43 = ad42 + ab43
            ad54 = ad53 + ab54
            ae43 = ae42 + ad43
            ae54 = ae53 + ad54
            af43 = af42 + ae43
            af54 = af53 + ae54
            ag43 = ag42 + af43
            ag54 = ag53 + af54
            ac44 = sum([ab42, ac42]) / -aa53
            ac55 = sum([ab53, ac53]) / -aa53
            ad44 = sum([ab42, ac42, ad42]) / -aa53
            ad55 = sum([ab53, ac53, ad53]) / -aa53
            ae44 = sum([ab42, ac42, ad42, ae42]) / -aa53
            ae55 = sum([ab53, ac53, ad53, ae53]) / -aa53
            af44 = sum([ab42, ac42, ad42, ae42, af42]) / -aa53
            af55 = sum([ab53, ac53, ad53, ae53, af53]) / -aa53
            ag44 = sum([ab42, ac42, ad42, ae42, af42, ag42]) / -aa53
            ag55 = sum([ab53, ac53, ad53, ae53, af53, ag53]) / -aa53

            c6 = calculate_c6(M5)

            f39 = ab38 if bonus_depreciation_used == 100 else ab49
            g39 = ad38 if bonus_depreciation_used == 100 else ad49
            h39 = ae38 if bonus_depreciation_used == 100 else ae49
            i39 = af38 if bonus_depreciation_used == 100 else af49
            j39 = ag38 if bonus_depreciation_used == 100 else ag49

            f41 = ab40 if bonus_depreciation_used == 100 else ab51
            g41 = ad40 if bonus_depreciation_used == 100 else ad51
            h41 = ae40 if bonus_depreciation_used == 100 else ae51
            i41 = af40 if bonus_depreciation_used == 100 else af51
            j41 = ag40 if bonus_depreciation_used == 100 else ag51

            ag8 = ag4 + (-ag4 * c14) + ag7
            ah8 = ah4 + (-ah4 * c14) + ah7
            ai8 = ai4 + (-ai4 * c14) + ai7
            aj8 = aj4 + (-aj4 * c14) + aj7
            ak8 = ak4 + (-ak4 * c14) + ak7
            al8 = al4 + (-al4 * c14) + al7
            am8 = am4 + (-am4 * c14) + am7
            an8 = an4 + (-an4 * c14) + an7
            ao8 = ao4 + (-ao4 * c14) + ao7
            ap8 = ap4 + (-ap4 * c14) + ap7
            aq8 = aq4 + (-aq4 * c14) + aq7
            ar8 = ar4 + (-ar4 * c14) + ar7
            as8 = as4 + (-as4 * c14) + as7
            at8 = at4 + (-at4 * c14) + at7
            au8 = au4 + (-au4 * c14) + au7
            av8 = av4 + (-av4 * c14) + av7
            aw8 = aw4 + (-aw4 * c14) + aw7
            ax8 = ax4 + (-ax4 * c14) + ax7
            ay8 = ay4 + (-ay4 * c14) + ay7
            az8 = az4 + (-az4 * c14) + az7
            ba8 = ba4 + (-ba4 * c14) + ba7
            bb8 = bb4 + (-bb4 * c14) + bb7
            bc8 = bc4 + (-bc4 * c14) + bc7
            bd8 = bd4 + (-bd4 * c14) + bd7
            be8 = be4 + (-be4 * c14) + be7
            bf8 = bf4 + (-bf4 * c14) + bf7
            bg8 = bg4 + (-bg4 * c14) + bg7
            bh8 = bh4 + (-bh4 * c14) + bh7
            bi8 = bi4 + (-bi4 * c14) + bi7
            bj8 = bj4 + (-bj4 * c14) + bj7
            bk8 = bk4 + (-bk4 * c14) + bk7

            # Year 7 cash flow adjustments:
            ah38 = 0
            ah39 = 0
            ah40 = solar_acquisition_price * k18 * tax_rate
            ah41 = ah8

            ah42 = ah38 + ah39 + ah40 + ah41
            ah43 = ah42 + ag43
            ah44 = sum([ab42, ac42, ad42, ae42, af42, ag42, ah42]) / -aa53

            ah49 = k17 * c17
            ah51 = solar_acquisition_price * k18 * tax_rate
            ah52 = ah8
            ah53 = ah49 + ah51 + ah52
            ah54 = ah53 + ag54
            ag55 = sum([ab53, ac53, ad53, ae53, af53, ag53, ah53]) / -aa53

            k39 = ah38 if bonus_depreciation_used == 100 else ah49
            k41 = ah40 if bonus_depreciation_used == 100 else ah51

            f42 = ac8
            g42 = ad8
            h42 = ae8
            i42 = af8
            j42 = ag8
            k42 = ah8

            f40 = ab39 if bonus_depreciation_used == 100 else ab50
            g40 = 0
            h40 = 0
            i40 = 0
            j40 = 0
            k40 = 0
            l40 = 0
            l39 = 0
            l41 = 0

            f43 = sum([f39, f40, f41, f42])
            g43 = sum([g39, g40, g41, g42])
            h43 = sum([h39, h40, h41, h42])
            i43 = sum([i39, i40, i41, i42])
            j43 = sum([j39, j40, j41, j42])
            k43 = sum([k39, k40, k41, k42])
            e43 = aa42 if bonus_depreciation_used == 100 else aa53

            f44 = e43 + f43
            g44 = f44 + g43
            h44 = g44 + h43
            i44 = h44 + i43
            j44 = i44 + j43
            k44 = j44 + k43

            l42 = sum([ac8, ad8, ae8, af8, ag8, ah8, ai8, aj8, ak8, al8, am8, an8, ao8, ap8, aq8, ar8, as8, at8, au8, av8, aw8, ax8, ay8, az8, ba8, bb8, bc8, bd8, be8, bf8, bg8, bh8, bi8, bj8, bk8, bl8]) - \
                  sum([year_1_cash_flow, year_2_cash_flow, year_3_cash_flow, year_4_cash_flow, year_5_cash_flow, year_6_cash_flow])
            l43 = sum([l39, l40, l41, l42])
            l44 = k44 + l43

            f45 = abs(f43 / e43)
            g45 = abs((f43 + g43) / e43)
            h45 = abs((f43 + g43 + h43) / e43)
            i45 = abs((f43 + g43 + h43 + i43) / e43)
            j45 = abs((f43 + g43 + h43 + i43 + j43) / e43)
            k45 = abs((f43 + g43 + h43 + i43 + j43 + k43) / e43)
            l45 = abs((f43 + g43 + h43 + i43 + j43 + k43 + l43) / e43)

            c44 = l45

            total_6_year_roi = sum([f43, g43, h43, i43, j43, k43])
            total_gross_benefit = l44 + total_cash_out_of_pocket

            # Build the final response dictionary with key output metrics.
            response = {
                'x11': c23,  # Cash portion of acquisition price
                'x12': c24,  # Financed portion of acquisition price
                'x2': solar_acquisition_price,
                'x13': round(tax_rate * 100),  # Tax rate (%)
                'x1': c6,  # Overall federal liability
                'x3': ab39 if bonus_depreciation_used == 100 else ab50,
                'x4': f39 + f41,
                'x5': ab43 if bonus_depreciation_used == 100 else ab54,
                'x6': ab44 * 100 if bonus_depreciation_used == 100 else ab55 * 100,
                'total_cash_out_of_pocket': total_cash_out_of_pocket,
                'total_gross_benefit': total_gross_benefit,
                'year_1_amount': ab42 if bonus_depreciation_used == 100 else ab53,
                'year_1_percent': ab44 * 100 if bonus_depreciation_used == 100 else ab55 * 100,
                'total_6_year_r': total_6_year_roi,
                'total_6_year_net_r': total_6_year_roi - total_cash_out_of_pocket,
                'full_6_year_percent': ag44 * 100 if bonus_depreciation_used == 100 else ag55 * 100,
                'full_return': c44,
                'year_1_fed': f39,
                'year_2_fed': g39,
                'year_3_fed': h39,
                'year_4_fed': i39,
                'year_5_fed': j39,
                'year_6_fed': k39,
                'year_7_fed': l39,
                'year_1_itc': f40,
                'year_2_itc': g40,
                'year_3_itc': h40,
                'year_4_itc': i40,
                'year_5_itc': j40,
                'year_6_itc': k40,
                'year_7_itc': l40,
                'year_1_st': f41,
                'year_2_st': g41,
                'year_3_st': h41,
                'year_4_st': i41,
                'year_5_st': j41,
                'year_6_st': k41,
                'year_7_st': l41,
                'year_1_cash_flow': f42,
                'year_2_cash_flow': g42,
                'year_3_cash_flow': h42,
                'year_4_cash_flow': i42,
                'year_5_cash_flow': j42,
                'year_6_cash_flow': k42,
                'year_7_cash_flow': l42,
                'year_1_net_benefit': f44,
                'year_2_net_benefit': g44,
                'year_3_net_benefit': h44,
                'year_4_net_benefit': i44,
                'year_5_net_benefit': j44,
                'year_6_net_benefit': k44,
                'year_7_net_benefit': l44,
                'year_1_roi': f45 * 100,
                'year_2_roi': g45 * 100,
                'year_3_roi': h45 * 100,
                'year_4_roi': i45 * 100,
                'year_5_roi': j45 * 100,
                'year_6_roi': k45 * 100,
                'year_7_roi': l45 * 100,
                'year_7_$': l43,
                'year_1_$': f43,
                'year_2_$': g43,
                'year_3_$': h43,
                'year_4_$': i43,
                'year_5_$': j43,
                'year_6_$': k43,
                'carbon_dioxide': solar_acquisition_price / 3 / 1000 * f6,
                'tree': solar_acquisition_price / 3 / 1000 * f7,
                'coal': solar_acquisition_price / 3 / 1000 * f8,
                'vehicle': solar_acquisition_price / 3 / 1000 * f9
            }

            # Helper function to format numbers with commas.
            def format_number_with_commas(number):
                rounded_number = round(number)
                return f"{rounded_number:,}"

            # Format each response value.
            response = {k: format_number_with_commas(round(v)) for k, v in response.items()}

            return Response(MultiplySerializer(response).data)
        return Response(serializer.errors, status=status.HTTP_400_BAD_REQUEST)


# =============================================================================
# CapitalGainsView
# =============================================================================
class CapitalGainsView(APIView):
    """
    API endpoint to handle capital gains inquiries.

    It sends an email with the capital gains message type and returns a simple confirmation message.
    """
    def post(self, request):
        serializer = MultiplySerializer(data=request.data)
        if serializer.is_valid():
            data = serializer.validated_data
            message = generate_message(**data, type='capital_gains')
            send_emails.delay("Solar Calculator", message, EMAILS)

            response = {'message': "Message!"}
            return Response(MultiplySerializer(response).data)
        return Response(serializer.errors, status=status.HTTP_400_BAD_REQUEST)


# =============================================================================
# UrgentMailView
# =============================================================================
class UrgentMailView(APIView):
    """
    API endpoint for urgent contact requests.

    This view sends an urgent contact email and returns a simple confirmation message.
    """
    def post(self, request):
        serializer = MultiplySerializer(data=request.data)
        if serializer.is_valid():
            data = serializer.validated_data
            message = generate_message(**data, type='urgent')
            send_emails.delay("Urgent contact requested!", message, EMAILS)

            response = {'message': "Message!"}
            return Response(MultiplySerializer(response).data)
        return Response(serializer.errors, status=status.HTTP_400_BAD_REQUEST)
